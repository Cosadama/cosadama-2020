# %% [markdown]
# # 🦉COSADAMA Introduction to Data Science Study
#
# - 일자: 2020-07-08
# - 작성자: 박하람
# - 참고자료: 데이터 사이언스 개론 수업(김학래 교수님, 2020년), Gephi와 네트워크 시각화로 시작하는 데이터 분석(센타, 에듀 캐스트), [NetworkX Tutorial](https://networkx.github.io/documentation/stable/tutorial.html)
#
#
# ## 9. 네트워크 분석 기초
#
# 이번 주차에는 Network Analysis 네트워크 분석을 해보려 합니다🐛 사회학에서도 중요한 분석 도구이기도 하고, 사회과학 대학에서 연구 주제로 잘 활용될 수 있어요. 회사에서 프로젝트를 하고나 분석할 때도 유용하게 쓰일 수 있을 것이구요. 이번에는 두가지 툴을 사용해서 네트워크 분석을 해볼 것인데요, 하나는 Gephi(지피, 게피, 제피 등 여러가지로 불립니다..ㅎㅎ)를 가지고, 다른 하나는 파이썬 모듈인 NetworkX를 가지고 분석해볼 겁니다.
#
# ### 9.1 Gephi를 이용한 네트워크 시각화
#
# 정확히 말하면 gephi는 네트워크 '시각화' 도구라고 할 수 있습니다. 오픈소스라 무료로 다운받을 수 있지만, 생각보다 사용법이 복잡합니다...ㅎㅎ 그래서 이를 잘 설명해주고 있는 강의를 가져와봤어요! [쎈타의 Gephi와 네트워크 시각화로 시작하는 데이터 분석](https://educast.com/course/datasci/ND63)을 수강(무료)하시고 아래 진도를 나가시면 됩니다. 네트워크 분석의 이론 또한 간단하게 설명해주시니 전부 수강해주시면 됩니다.
#
# 실습은 3가지로, 1) Les Miserables 2) Facebook Food Network 3) Facebook Artist Network인데요, 실습을 진행하신 후 시각화를 캡처하여 구글 드라이브에 올려주시면 과제는 완성! 다만, 3번의 경우 데이터가 아~주 커서 맥북 프로를 사용하고 있는 제 컴퓨터가 실행하다 맛탱이가 가버렸습니다...ㅎㅎ 그래서 3)은 굳이 하지 않으셔도 되지만, 강의를 쭉 보시면 아주 데이터가 큰 네트워크 분석은 어떻게 시각화하고 분석할 수 있는지 감이 오실꺼니 강의는 꼭 보시길 추천드려요!
#
# ### 9.2 NetworkX: Network Analysis with Python
#
# 파이썬에서 네트워크 분석을 할 수 있는 모듈은 NetworkX라는 모듈입니다. networkx를 사용하면 파이썬에서 사용할 수 있는 다양한 라이브러리들(판다스, 넘파이 등)도 함께 사용할 수 있다는 점에서 유용하다고 볼 수 있겠지요!
#
# 자료가 영어라 딱히 번역하지는 않았습니다~ 영어로 느껴보세요ㅋㅋㅋ(사실 번역하기 귀찮았음.) 우리 새로운거 많이 배웠잖아요~ 이제 짬에서 나오는 바이브로 networkX를 배워봅시다..👍😊
#
# #### 9.2.1 Introduction to NetworkX
#
# #### network analysis
#
# Vast amounts of network data are being generated and collected
# -  Sociology: web pages, mobile phones, social networks
# -  Technology: Internet routers, vehicular flows, power grids
#
# #### official website - [NetworkX Tutorial] 참고(https://networkx.github.io/documentation/stable/tutorial.html)
#
# #### A basic example
#
# 1. Generate a graph using networkx
# 2. Draw the graph
# 3. Save the drawing graph

# %%
# 명령 프롬프트에 깔아주는 것 잊지말기
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/site-packages (2.4)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/site-packages (from networkx) (4.4.1)

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# 객체 생성 
g = nx.Graph()
# 노드 추가
g.add_edge('a','b',weight=0.1)
g.add_edge('b','c',weight=2.0)
g.add_edge('a','c',weight=5.0)
g.add_edge('c','d',weight=2.2)

# %%
# 그림을 그려라! 
nx.draw(g, with_labels = True, weight=True)
# plt.savefig('exampl.png') - 이미지 저장

# %% [markdown]
# 아주 간단한 노드를 그려보았습니다. 이런 방식으로 노드와 엣지가 그려진다고 생각하시면 됩니다.
#
# #### 9.2.2 Getting started with Python and NetworkX
#
# #### add nodes

# %%
g = nx.Graph()

# %%
# one node at a time 
g.add_node(1)
nx.draw(g, with_labels = True)

# %%
g.add_nodes_from([2,3])
nx.draw(g, with_labels = True)

# %%
# A container of nodes
h = nx.path_graph(10)
g.add_nodes_from(h) # g now contains the nodes of h
nx.draw(g, with_labels = True)

# %%
# In contrast, you can remove any node of the graph
g.remove_node(2)
nx.draw(g, with_labels = True) # node 2가 사라지고 9개만 남음

# %% [markdown]
# #### node entities
#
# A node can be any hashable object such as strings, numbers, files, functions, and more. This provides important flexibility for all your projects.

# %%
import math 
g.add_node(math.cos) # 코사인
fh = open('tmp.txt','w') # 파일에다 쓰기
g.add_node(fh) # fh에 노드 그리기 
print(g.nodes())
# Out:
# [1, 3, 0, 4, 5, 6, 7, 8, 9, <built-in function cos>, <_io.TextIOWrapper name='tmp.txt' mode='w' encoding='UTF-8'>]

# %% [markdown]
# #### add edges

# %%
# single edge 
g.add_edge(1,2)
e=(2,3)
g.add_edge(*e) # unpack edge tuple
nx.draw(g)

# %%
# list of edges 
g.add_edges_from([(1,2), (1,3)])
nx.draw(g)

# %%
# container of edges 
g.add_edges_from(h.edges()) 
nx.draw(g)

# %%
# In contrast, you can remove any edge of the graph
g.remove_edge(1,2)
nx.draw(g)

# %% [markdown]
# #### access nodes and edges

# %%
g = nx.Graph()
g.add_edges_from([(1,2),(1,3)])
print(nx.draw(g, with_labels=True))
# Out:
# None

# %%
g.add_node('a')
print(nx.draw(g, with_labels=True))
# Out:
# None

# %%
print('노드 수:',g.number_of_nodes())
print('연결선 수:', g.number_of_edges())
# Out:
# 노드 수: 4
# 연결선 수: 2

# %%
g.nodes
# Out:
# NodeView((1, 2, 3, 'a'))

# %%
g.edges
# Out:
# EdgeView([(1, 2), (1, 3)])

# %%
g.degree
# Out:
# DegreeView({1: 2, 2: 1, 3: 1, 'a': 0})

# %%
# 인접
g.adj
# Out:
# AdjacencyView({1: {2: {}, 3: {}}, 2: {1: {}}, 3: {1: {}}, 'a': {}})

# %%
print(nx.info(g))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4
# Number of edges: 2
# Average degree:   1.0000

# %% [markdown]
# #### directed graph

# %%
g2 = nx.DiGraph()

g2.add_edges_from([(1,2),(1,3),(2,4),(3,4)])

nx.draw(g2, with_labels=True, font_weigth='bold')

# %%
g2.degree
# Out:
# DiDegreeView({1: 2, 2: 2, 3: 2, 4: 2})

# %%
g2.in_degree
# Out:
# InDegreeView({1: 0, 2: 1, 3: 1, 4: 2})

# %%
g2.out_degree
# Out:
# OutDegreeView({1: 2, 2: 1, 3: 1, 4: 0})

# %% [markdown]
# Any NetworkX graph behaves like a Python dictionary with nodes as primary keys

# %%
g = nx.Graph()
g.add_edge(1,2, weight=4.0) # 가중치 4만큼!
g[1][2]['weight'] = 5.0 # 가중치 5로 change
g[1][2]
# Out:
# {'weight': 5.0}

# %%
nx.draw(g, with_labels=True)

# %% [markdown]
# #### node and edge iterators
#
# Many applications require iteration over nodes or over edges: simple and easy in NetworkX

# %%
g = nx.Graph()
g.add_edge(1,2)
for node in g.nodes(): 
    print(node, g.degree(node))
# Out:
# 1 1
# 2 1

# %%
g.add_edge(1,3, weight=2.5)
g[1][2]['weight'] = 1.5
for n1, n2, attr in g.edges(data=True): 
    print(n1, n2, attr['weight'])
# Out:
# 1 2 1.5
# 1 3 2.5

# %% [markdown]
# #### 9.2.3 Drawing graphs
#
# #### Layout of a graph
#
# ![layouts](https://frhyme.github.io/assets/images/markdown_img/180807_nx_layout_comp.svg)

# %%
g = nx.Graph()

# %%
g.add_edge(1,2)
g.add_edge(2,3)
g.add_edge(3,4)
g.add_edge(4,5)
g.add_edge(6,7)
g.add_edge(1,4)
g.add_edge(1,5)
g.add_edge(2,4)
g.add_edge(4,7)
g.add_edge(4,8)

# %%
nx.draw(g)

# %%
# a circular layout 
nx.draw_circular(g, with_labels = True)

# %%
# clearing the current plot 깨끗하게 지우기! 
plt.clf()

# %%
# Draw the graph G with a random layout.
nx.draw_random(g,with_labels=True)

# %%
plt.clf()

# %%
# planar layout 
nx.draw_planar(g, with_labels = True)
# Out:
# /usr/local/lib/python3.7/site-packages/networkx/drawing/layout.py:950: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   pos = np.row_stack((pos[x] for x in node_list))

# %%
plt.clf()

# %%
# shell layout 
nx.draw_shell(g, with_labels = True)

# %%
plt.clf()

# %%
# spring layout 
nx.draw_spring(g, with_labels=True)

# %%
options = {
    'node_color': 'black',
    'node_size': 100,
    'width':3
}
nx.draw_random(g, **options)

# %% [markdown]
# #### Using the pre-built graph

# %%
# Load the graph - 내장된 노드 데이터 
g = nx.karate_club_graph()
# Find key-values for the graph
pos = nx.spring_layout(g)
# Plot the graph
nx.draw(g, node_color=range(34), node_size=300, 
        cmap=plt.get_cmap('rainbow'),
        with_labels=True, pos=pos)

# %%
# 얼마만큼 연결되어 있는지 알려주는 지표 
g.degree()
# Out:
# DegreeView({0: 16, 1: 9, 2: 10, 3: 6, 4: 3, 5: 4, 6: 4, 7: 4, 8: 5, 9: 2, 10: 3, 11: 1, 12: 2, 13: 5, 14: 2, 15: 2, 16: 2, 17: 2, 18: 2, 19: 3, 20: 2, 21: 2, 22: 2, 23: 5, 24: 3, 25: 3, 26: 2, 27: 4, 28: 3, 29: 4, 30: 4, 31: 6, 32: 12, 33: 17})

# %%
# Isolate the sequence of degrees - 따로 떨어뜨려주기
degree_sequence = list(g.degree())
degree_sequence[:5]
# Out:
# [(0, 16), (1, 9), (2, 10), (3, 6), (4, 3)]

# %%
# 노드 수
nb_nodes = 34
# 연결선 수
nb_arr = len(g.edges())
# np.array로 바꾸어줘야 넘파이 연산 가능, 오른쪽 기준 계산
avg_degree = np.mean(np.array(degree_sequence)[:,1])
med_degree = np.median(np.array(degree_sequence)[:,1])
max_degree = max(np.array(degree_sequence)[:,1])
min_degree = np.min(np.array(degree_sequence)[:,1])

# %%
print("Number of nodes : " + str(nb_nodes))
print("Number of edges : " + str(nb_arr))
print("Maximum degree : " + str(max_degree))
print("Minimum degree : " + str(min_degree))
print("Average degree : " + str(avg_degree))
print("Median degree : " + str(med_degree))
# Out:
# Number of nodes : 34
# Number of edges : 78
# Maximum degree : 17
# Minimum degree : 1
# Average degree : 4.588235294117647
# Median degree : 3.0

# %% [markdown]
# #### 9.2.4 Case study with Facebook data
#
# csv 파일을 코드로 열기 전에 직접 파일을 열어 어떻게 데이터가 구성되어 있는지 확인해보세요. 저런 방식으로 데이터들을 만들 수 있습니다.

# %%
import pandas as pd

# %%
df = pd.read_csv('facebook_combined.txt')
df.head()
# Out:
#    0 1
# 0  0 2
# 1  0 3
# 2  0 4
# 3  0 5
# 4  0 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88233 entries, 0 to 88232
# Data columns (total 1 columns):
# 0 1    88233 non-null object
# dtypes: object(1)
# memory usage: 689.4+ KB

# %%
# Read a graph from a list of edges
g = nx.read_edgelist('facebook_combined.txt', 
                     create_using=nx.Graph(),
                    nodetype=int)

# %%
print(nx.info(g))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4039
# Number of edges: 88234
# Average degree:  43.6910

# %% [markdown]
# 데이터가 커서 시간이 오~래 걸립니다. 제 컴퓨터로 2-3분 소요돼요.

# %%
plt.figure(figsize=(20,20))
nx.draw_networkx(g)

# %% [markdown]
# 이 데이터에서 중심부를 찾아볼게요. 중심부를 찾는 방법에는 여러가지가 있지만 이 중에서 betweenness centrality를 사용해볼 겁니다. betweenness centrality에 대한 간단한 개념은 gephi 강의에서 들었을 겁니다..ㅎㅎ
#
# - betweenness centrality를 사용: [네트워크의 모든 노드 쌍 간의 shortest path가 해당 노드를 지나는지 고려한 centrality](https://frhyme.github.io/python-lib/network-centrality/)
# - [normalized / endpoints 설명](https://networkx.github.io/documentation/networkx-1.10/reference/generated/networkx.algorithms.centrality.betweenness_centrality.html)
# - 이것 또한 시간이 오~래 걸려요!

# %%
pos = nx.spring_layout(g)
betCent = nx.betweenness_centrality(g, normalized=True, 
                                   endpoints=True)
node_color = [2000.0 * g.degree(v) for v in g]
node_size = [v * 10000 for v in betCent.values()]

plt.figure(figsize=(20,20))
nx.draw_networkx(g, pos=pos, with_labels=False,
                node_color=node_color,
                node_size=node_size)
plt.axis('off')
# Out:
# (-0.43634353832657197,
#  0.6095460417524365,
#  -0.7731417887363915,
#  1.0855074398670677)

# %% [markdown]
# 이렇게 어마무시하고 약간 징그러운 그래프가 나오게 됐네요ㅎㅎ
#
# ### 공부를 마치며
#
# Gephi와 networkX를 새롭게 배워봤는데, 어떠셨나요? Gephi 강의를 들으면서 어떻게 네트워크 분석을 사용할지에 대해 약간은 감은 잡으셨을거라 생각해요. 이번 주차의 내용은 즈엉말 맛보기에 불과하고, 어느정도 방향을 제시했으니 앞으로 네트워크 분석을 하고 싶다면 이를 더 심도있게 공부해서 하나씩 더 배워가면 되겠지요~!🌝 이번 주차 공부도 하느라 무척 고생했구요, 이제 코사다마의 마지막 스터디! **자연어 처리 기초**만이 남아있습니다! 한주만 더 힘내서 공부하고 유종의 미를 잘 거두어 봅시다!
